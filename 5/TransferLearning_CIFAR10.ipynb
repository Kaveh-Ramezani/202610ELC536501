# %% [markdown]
# # Imports

# %%
# PyTorch
import torch
print(f"Is CUDA available? {torch.cuda.is_available()}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}")
print(f"CUDA Version: {torch.version.cuda}")
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as nnFunc
import torch.amp as amp
# General
import numpy as np
import matplotlib.pyplot as plt
# Optimizer
import torch.optim as optim
# pretty print
from pprint import pprint
# Out:
# Is CUDA available? True
# GPU Name: NVIDIA GeForce RTX 5050 Laptop GPU
# CUDA Version: 13.0

# %% [markdown]
# ## Dataset
#
# This code uses the CIFAR-10 dataset.
# (https://www.cs.toronto.edu/~kriz/cifar.html)

# %% [markdown]
# ## 1. Transform setting
# The original images are in PIL (0 to 255 for each pixel). First we convert it to a tensor format (0 to 1). Then to make the data to be zero centering, we make the range to be between -1 to 1. If we use the following equation for each data, we can make it zero centered:
# \begin{equation}
#   output = \frac{input - mean}{std}
# \end{equation}
# This is being done by setting the `mean` and `standard deviation` to be 0.5.

# %%
transform = transforms.Compose([  transforms.RandomHorizontalFlip(),
                                transforms.RandomCrop(32, padding=4),
                                transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                ])

# %% [markdown]
# ## 2. Making the training set
# Now we load the actual dataset and make the training dataset.
# 1. Load CIFAR10 dataset (Download and prepare dataset)
#     1. Put it in `./data_CIFAR10` directory.
#     2. Download it
#     3. Do the specified transformation on the dataset
# 2. Create the data loader (pipelining settings)
#     1. Brake it to batches with size of 32
#     2. Shuffle the deck in every epoch
#     3. Use 4 number of workers to make the training faster

# %%
batchSize = 256
numberOfWorkers = 0

trainSet = torchvision.datasets.CIFAR10(root='./data_CIFAR10',
                                        train=True,
                                        download=True,
                                        transform = transform)

trainLoader = torch.utils.data.DataLoader(trainSet,
                                          batch_size=batchSize,
                                          shuffle=True,
                                          num_workers=numberOfWorkers,
                                          pin_memory=True,
                                          persistent_workers=False)

# %% [markdown]
# ## 3. Making the test set
# Now making the test set. The procedure is the same as making the training set with some minor modifications.

# %%
testSet = torchvision.datasets.CIFAR10(root='./data_CIFAR10',
                                       train=False,
                                       download=True,
                                       transform=transform)

testLoader = torch.utils.data.DataLoader(testSet,
                                         batch_size=batchSize,
                                         shuffle=False,
                                         num_workers=numberOfWorkers,
                                         pin_memory=True,
                                         persistent_workers=False) # Updated here too
viz_batchSize = 4
vizLoader = torch.utils.data.DataLoader(testSet, batch_size=viz_batchSize, shuffle=True)

# %% [markdown]
# ## 4. The classes

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
pprint(classes)
# Out:
# ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ## DEUBG1
# Showing some of the images from the dataset.

# %%
# functions to show an image
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()
# get some random training images
dataiter = iter(vizLoader)
images, labels = next(dataiter)
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
pprint(' '.join(f'{classes[labels[j]]:5s}' for j in range(viz_batchSize)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8183348].
# 'bird  deer  truck plane'

# %% [markdown]
# ## 5. Defining the CNN model

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3)
    self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
    self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
    self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
    self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3)
    self.fc1 = nn.Linear(64 * 4 * 4, 64)
    self.fc2 = nn.Linear(64, 10)

  def forward(self, x):
    x = self.pool1(nnFunc.relu(self.conv1(x)))
    x = self.pool2(nnFunc.relu(self.conv2(x)))
    x = nnFunc.relu(self.conv3(x))

    x = x.view(-1, 64 * 4 * 4)

    x = nnFunc.relu(self.fc1(x))
    x = self.fc2(x)
    
    return x

# %% [markdown]
# ## 6. Instansiating the CNN model

# %%
def init_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
net = Net()
net.apply(init_weights)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## 7. Move the model to GPU

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## 8. Degine loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=10)

# %% [markdown]
# ## 9. Traing the network

# %%
scaler = amp.GradScaler('cuda')

epochs = 100
printFrequency = len(trainLoader) // 4

for epoch in range(epochs):
    net.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    # --- TRAINING PHASE ---
    for i, data in enumerate(trainLoader, 0):
        inputs, labels = data[0].to(device, non_blocking=True), data[1].to(device, non_blocking=True)
        
        optimizer.zero_grad()
        
        with amp.autocast('cuda'):
            outputs = net(inputs)
            loss = criterion(outputs, labels)
        
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()
        
        if i % printFrequency == (printFrequency - 1):
            accuracy = 100 * correct / total
            print(f'Epoch {epoch + 1} | Batch {i + 1}/{len(trainLoader)} | loss: {running_loss / printFrequency:.3f} | acc: {accuracy:.2f}%')
            running_loss, correct, total = 0.0, 0, 0

    # --- VALIDATION PHASE ---
    net.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in testLoader:
            images, labels = data[0].to(device), data[1].to(device)
            with amp.autocast('cuda'):
                outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_acc = 100 * val_correct / val_total
    current_lr = optimizer.param_groups[0]['lr']
    print(f'>> Epoch {epoch + 1} SUMMARY: Val Acc: {val_acc:.2f}% | Current LR: {current_lr}')
    
    # --- AUTOMATIC LR DROP ---
    scheduler.step(val_acc)

print('Finished Training')
# Out:
# Epoch 1 | Batch 49/196 | loss: 3.281 | acc: 19.40%
# Epoch 1 | Batch 98/196 | loss: 1.880 | acc: 31.38%
# Epoch 1 | Batch 147/196 | loss: 1.695 | acc: 37.87%
# Epoch 1 | Batch 196/196 | loss: 1.629 | acc: 40.38%
# >> Epoch 1 SUMMARY: Val Acc: 41.42% | Current LR: 0.001
# Epoch 2 | Batch 49/196 | loss: 1.559 | acc: 42.85%
# Epoch 2 | Batch 98/196 | loss: 1.496 | acc: 45.25%
# Epoch 2 | Batch 147/196 | loss: 1.466 | acc: 46.25%
# Epoch 2 | Batch 196/196 | loss: 1.441 | acc: 47.99%
# >> Epoch 2 SUMMARY: Val Acc: 48.45% | Current LR: 0.001
# Epoch 3 | Batch 49/196 | loss: 1.404 | acc: 49.59%
# Epoch 3 | Batch 98/196 | loss: 1.364 | acc: 51.27%
# Epoch 3 | Batch 147/196 | loss: 1.307 | acc: 53.07%
# Epoch 3 | Batch 196/196 | loss: 1.280 | acc: 54.09%
# >> Epoch 3 SUMMARY: Val Acc: 52.99% | Current LR: 0.001
# Epoch 4 | Batch 49/196 | loss: 1.285 | acc: 54.15%
# Epoch 4 | Batch 98/196 | loss: 1.239 | acc: 55.75%
# Epoch 4 | Batch 147/196 | loss: 1.225 | acc: 56.61%
# Epoch 4 | Batch 196/196 | loss: 1.222 | acc: 56.51%
# >> Epoch 4 SUMMARY: Val Acc: 56.57% | Current LR: 0.001
# Epoch 5 | Batch 49/196 | loss: 1.178 | acc: 58.09%
# Epoch 5 | Batch 98/196 | loss: 1.177 | acc: 58.53%
# Epoch 5 | Batch 147/196 | loss: 1.169 | acc: 58.45%
# Epoch 5 | Batch 196/196 | loss: 1.159 | acc: 59.18%
# >> Epoch 5 SUMMARY: Val Acc: 55.53% | Current LR: 0.001
# Epoch 6 | Batch 49/196 | loss: 1.134 | acc: 59.65%
# Epoch 6 | Batch 98/196 | loss: 1.121 | acc: 60.62%
# Epoch 6 | Batch 147/196 | loss: 1.137 | acc: 59.59%
# Epoch 6 | Batch 196/196 | loss: 1.103 | acc: 60.74%
# >> Epoch 6 SUMMARY: Val Acc: 59.10% | Current LR: 0.001
# Epoch 7 | Batch 49/196 | loss: 1.101 | acc: 61.17%
# Epoch 7 | Batch 98/196 | loss: 1.072 | acc: 61.92%
# Epoch 7 | Batch 147/196 | loss: 1.068 | acc: 62.49%
# Epoch 7 | Batch 196/196 | loss: 1.081 | acc: 61.64%
# >> Epoch 7 SUMMARY: Val Acc: 62.72% | Current LR: 0.001
# Epoch 8 | Batch 49/196 | loss: 1.043 | acc: 62.98%
# Epoch 8 | Batch 98/196 | loss: 1.030 | acc: 63.16%
# Epoch 8 | Batch 147/196 | loss: 1.037 | acc: 63.25%
# Epoch 8 | Batch 196/196 | loss: 1.018 | acc: 64.68%
# >> Epoch 8 SUMMARY: Val Acc: 64.98% | Current LR: 0.001
# Epoch 9 | Batch 49/196 | loss: 0.984 | acc: 65.19%
# Epoch 9 | Batch 98/196 | loss: 1.006 | acc: 64.63%
# Epoch 9 | Batch 147/196 | loss: 1.003 | acc: 64.66%
# Epoch 9 | Batch 196/196 | loss: 0.993 | acc: 65.24%
# >> Epoch 9 SUMMARY: Val Acc: 64.12% | Current LR: 0.001
# Epoch 10 | Batch 49/196 | loss: 0.953 | acc: 66.18%
# Epoch 10 | Batch 98/196 | loss: 0.989 | acc: 65.27%
# Epoch 10 | Batch 147/196 | loss: 0.952 | acc: 66.29%
# Epoch 10 | Batch 196/196 | loss: 0.954 | acc: 66.36%
# >> Epoch 10 SUMMARY: Val Acc: 65.99% | Current LR: 0.001
# Epoch 11 | Batch 49/196 | loss: 0.947 | acc: 66.93%
# Epoch 11 | Batch 98/196 | loss: 0.952 | acc: 66.74%
# Epoch 11 | Batch 147/196 | loss: 0.928 | acc: 67.68%
# Epoch 11 | Batch 196/196 | loss: 0.946 | acc: 66.39%
# >> Epoch 11 SUMMARY: Val Acc: 66.59% | Current LR: 0.001
# Epoch 12 | Batch 49/196 | loss: 0.907 | acc: 68.18%
# Epoch 12 | Batch 98/196 | loss: 0.933 | acc: 67.36%
# Epoch 12 | Batch 147/196 | loss: 0.892 | acc: 68.18%
# Epoch 12 | Batch 196/196 | loss: 0.920 | acc: 67.71%
# >> Epoch 12 SUMMARY: Val Acc: 67.84% | Current LR: 0.001
# Epoch 13 | Batch 49/196 | loss: 0.896 | acc: 68.97%
# Epoch 13 | Batch 98/196 | loss: 0.900 | acc: 68.26%
# Epoch 13 | Batch 147/196 | loss: 0.900 | acc: 68.69%
# Epoch 13 | Batch 196/196 | loss: 0.895 | acc: 68.82%
# >> Epoch 13 SUMMARY: Val Acc: 67.35% | Current LR: 0.001
# Epoch 14 | Batch 49/196 | loss: 0.874 | acc: 69.51%
# Epoch 14 | Batch 98/196 | loss: 0.858 | acc: 70.04%
# Epoch 14 | Batch 147/196 | loss: 0.866 | acc: 69.64%
# Epoch 14 | Batch 196/196 | loss: 0.864 | acc: 70.08%
# >> Epoch 14 SUMMARY: Val Acc: 69.25% | Current LR: 0.001
# Epoch 15 | Batch 49/196 | loss: 0.862 | acc: 69.71%
# Epoch 15 | Batch 98/196 | loss: 0.865 | acc: 69.49%
# Epoch 15 | Batch 147/196 | loss: 0.846 | acc: 70.36%
# Epoch 15 | Batch 196/196 | loss: 0.849 | acc: 70.63%
# >> Epoch 15 SUMMARY: Val Acc: 69.14% | Current LR: 0.001
# Epoch 16 | Batch 49/196 | loss: 0.840 | acc: 70.67%
# Epoch 16 | Batch 98/196 | loss: 0.824 | acc: 71.39%
# Epoch 16 | Batch 147/196 | loss: 0.826 | acc: 70.96%
# Epoch 16 | Batch 196/196 | loss: 0.835 | acc: 70.44%
# >> Epoch 16 SUMMARY: Val Acc: 68.57% | Current LR: 0.001
# Epoch 17 | Batch 49/196 | loss: 0.811 | acc: 71.53%
# Epoch 17 | Batch 98/196 | loss: 0.831 | acc: 71.05%
# Epoch 17 | Batch 147/196 | loss: 0.821 | acc: 71.44%
# Epoch 17 | Batch 196/196 | loss: 0.825 | acc: 70.84%
# >> Epoch 17 SUMMARY: Val Acc: 71.32% | Current LR: 0.001
# Epoch 18 | Batch 49/196 | loss: 0.796 | acc: 72.60%
# Epoch 18 | Batch 98/196 | loss: 0.809 | acc: 71.46%
# Epoch 18 | Batch 147/196 | loss: 0.816 | acc: 71.23%
# Epoch 18 | Batch 196/196 | loss: 0.792 | acc: 72.07%
# >> Epoch 18 SUMMARY: Val Acc: 70.72% | Current LR: 0.001
# Epoch 19 | Batch 49/196 | loss: 0.788 | acc: 72.50%
# Epoch 19 | Batch 98/196 | loss: 0.806 | acc: 71.90%
# Epoch 19 | Batch 147/196 | loss: 0.791 | acc: 72.46%
# Epoch 19 | Batch 196/196 | loss: 0.796 | acc: 72.37%
# >> Epoch 19 SUMMARY: Val Acc: 70.44% | Current LR: 0.001
# Epoch 20 | Batch 49/196 | loss: 0.767 | acc: 73.44%
# Epoch 20 | Batch 98/196 | loss: 0.776 | acc: 73.27%
# Epoch 20 | Batch 147/196 | loss: 0.781 | acc: 72.65%
# Epoch 20 | Batch 196/196 | loss: 0.772 | acc: 72.72%
# >> Epoch 20 SUMMARY: Val Acc: 72.24% | Current LR: 0.001
# Epoch 21 | Batch 49/196 | loss: 0.763 | acc: 73.87%
# Epoch 21 | Batch 98/196 | loss: 0.780 | acc: 72.94%
# Epoch 21 | Batch 147/196 | loss: 0.752 | acc: 73.76%
# Epoch 21 | Batch 196/196 | loss: 0.778 | acc: 72.71%
# >> Epoch 21 SUMMARY: Val Acc: 72.18% | Current LR: 0.001
# Epoch 22 | Batch 49/196 | loss: 0.745 | acc: 73.71%
# Epoch 22 | Batch 98/196 | loss: 0.761 | acc: 73.56%
# Epoch 22 | Batch 147/196 | loss: 0.751 | acc: 73.65%
# Epoch 22 | Batch 196/196 | loss: 0.756 | acc: 73.81%
# >> Epoch 22 SUMMARY: Val Acc: 72.77% | Current LR: 0.001
# Epoch 23 | Batch 49/196 | loss: 0.755 | acc: 73.57%
# Epoch 23 | Batch 98/196 | loss: 0.738 | acc: 74.39%
# Epoch 23 | Batch 147/196 | loss: 0.732 | acc: 74.63%
# Epoch 23 | Batch 196/196 | loss: 0.742 | acc: 73.96%
# >> Epoch 23 SUMMARY: Val Acc: 72.83% | Current LR: 0.001
# Epoch 24 | Batch 49/196 | loss: 0.722 | acc: 74.95%
# Epoch 24 | Batch 98/196 | loss: 0.734 | acc: 74.39%
# Epoch 24 | Batch 147/196 | loss: 0.726 | acc: 74.79%
# Epoch 24 | Batch 196/196 | loss: 0.731 | acc: 74.81%
# >> Epoch 24 SUMMARY: Val Acc: 73.55% | Current LR: 0.001
# Epoch 25 | Batch 49/196 | loss: 0.715 | acc: 75.02%
# Epoch 25 | Batch 98/196 | loss: 0.728 | acc: 74.81%
# Epoch 25 | Batch 147/196 | loss: 0.721 | acc: 74.72%
# Epoch 25 | Batch 196/196 | loss: 0.721 | acc: 74.99%
# >> Epoch 25 SUMMARY: Val Acc: 72.78% | Current LR: 0.001
# Epoch 26 | Batch 49/196 | loss: 0.715 | acc: 75.29%
# Epoch 26 | Batch 98/196 | loss: 0.715 | acc: 75.40%
# Epoch 26 | Batch 147/196 | loss: 0.730 | acc: 74.57%
# Epoch 26 | Batch 196/196 | loss: 0.698 | acc: 75.44%
# >> Epoch 26 SUMMARY: Val Acc: 72.45% | Current LR: 0.001
# Epoch 27 | Batch 49/196 | loss: 0.694 | acc: 75.86%
# Epoch 27 | Batch 98/196 | loss: 0.709 | acc: 74.95%
# Epoch 27 | Batch 147/196 | loss: 0.693 | acc: 75.57%
# Epoch 27 | Batch 196/196 | loss: 0.706 | acc: 75.65%
# >> Epoch 27 SUMMARY: Val Acc: 74.29% | Current LR: 0.001
# Epoch 28 | Batch 49/196 | loss: 0.687 | acc: 76.16%
# Epoch 28 | Batch 98/196 | loss: 0.694 | acc: 75.93%
# Epoch 28 | Batch 147/196 | loss: 0.685 | acc: 76.11%
# Epoch 28 | Batch 196/196 | loss: 0.696 | acc: 76.08%
# >> Epoch 28 SUMMARY: Val Acc: 73.77% | Current LR: 0.001
# Epoch 29 | Batch 49/196 | loss: 0.675 | acc: 76.67%
# Epoch 29 | Batch 98/196 | loss: 0.677 | acc: 76.43%
# Epoch 29 | Batch 147/196 | loss: 0.698 | acc: 75.42%
# Epoch 29 | Batch 196/196 | loss: 0.711 | acc: 75.25%
# >> Epoch 29 SUMMARY: Val Acc: 74.72% | Current LR: 0.001
# Epoch 30 | Batch 49/196 | loss: 0.678 | acc: 76.24%
# Epoch 30 | Batch 98/196 | loss: 0.686 | acc: 76.46%
# Epoch 30 | Batch 147/196 | loss: 0.679 | acc: 76.28%
# Epoch 30 | Batch 196/196 | loss: 0.670 | acc: 76.48%
# >> Epoch 30 SUMMARY: Val Acc: 74.95% | Current LR: 0.001
# Epoch 31 | Batch 49/196 | loss: 0.671 | acc: 76.59%
# Epoch 31 | Batch 98/196 | loss: 0.667 | acc: 77.27%
# Epoch 31 | Batch 147/196 | loss: 0.678 | acc: 76.41%
# Epoch 31 | Batch 196/196 | loss: 0.662 | acc: 77.28%
# >> Epoch 31 SUMMARY: Val Acc: 74.94% | Current LR: 0.001
# Epoch 32 | Batch 49/196 | loss: 0.667 | acc: 76.91%
# Epoch 32 | Batch 98/196 | loss: 0.671 | acc: 76.83%
# Epoch 32 | Batch 147/196 | loss: 0.670 | acc: 76.75%
# Epoch 32 | Batch 196/196 | loss: 0.657 | acc: 76.88%
# >> Epoch 32 SUMMARY: Val Acc: 75.10% | Current LR: 0.001
# Epoch 33 | Batch 49/196 | loss: 0.666 | acc: 77.22%
# Epoch 33 | Batch 98/196 | loss: 0.671 | acc: 76.71%
# Epoch 33 | Batch 147/196 | loss: 0.653 | acc: 77.26%
# Epoch 33 | Batch 196/196 | loss: 0.647 | acc: 77.24%
# >> Epoch 33 SUMMARY: Val Acc: 75.17% | Current LR: 0.001
# Epoch 34 | Batch 49/196 | loss: 0.644 | acc: 77.56%
# Epoch 34 | Batch 98/196 | loss: 0.664 | acc: 77.01%
# Epoch 34 | Batch 147/196 | loss: 0.656 | acc: 77.29%
# Epoch 34 | Batch 196/196 | loss: 0.644 | acc: 77.71%
# >> Epoch 34 SUMMARY: Val Acc: 75.54% | Current LR: 0.001
# Epoch 35 | Batch 49/196 | loss: 0.632 | acc: 78.09%
# Epoch 35 | Batch 98/196 | loss: 0.651 | acc: 77.56%
# Epoch 35 | Batch 147/196 | loss: 0.636 | acc: 77.74%
# Epoch 35 | Batch 196/196 | loss: 0.645 | acc: 77.11%
# >> Epoch 35 SUMMARY: Val Acc: 75.13% | Current LR: 0.001
# Epoch 36 | Batch 49/196 | loss: 0.630 | acc: 78.43%
# Epoch 36 | Batch 98/196 | loss: 0.641 | acc: 77.72%
# Epoch 36 | Batch 147/196 | loss: 0.643 | acc: 77.40%
# Epoch 36 | Batch 196/196 | loss: 0.641 | acc: 77.71%
# >> Epoch 36 SUMMARY: Val Acc: 74.95% | Current LR: 0.001
# Epoch 37 | Batch 49/196 | loss: 0.645 | acc: 77.73%
# Epoch 37 | Batch 98/196 | loss: 0.629 | acc: 78.24%
# Epoch 37 | Batch 147/196 | loss: 0.619 | acc: 78.60%
# Epoch 37 | Batch 196/196 | loss: 0.643 | acc: 77.70%
# >> Epoch 37 SUMMARY: Val Acc: 75.10% | Current LR: 0.001
# Epoch 38 | Batch 49/196 | loss: 0.627 | acc: 78.52%
# Epoch 38 | Batch 98/196 | loss: 0.637 | acc: 77.86%
# Epoch 38 | Batch 147/196 | loss: 0.616 | acc: 78.26%
# Epoch 38 | Batch 196/196 | loss: 0.608 | acc: 78.78%
# >> Epoch 38 SUMMARY: Val Acc: 75.27% | Current LR: 0.001
# Epoch 39 | Batch 49/196 | loss: 0.639 | acc: 77.67%
# Epoch 39 | Batch 98/196 | loss: 0.609 | acc: 78.70%
# Epoch 39 | Batch 147/196 | loss: 0.623 | acc: 78.32%
# Epoch 39 | Batch 196/196 | loss: 0.617 | acc: 78.40%
# >> Epoch 39 SUMMARY: Val Acc: 75.78% | Current LR: 0.001
# Epoch 40 | Batch 49/196 | loss: 0.598 | acc: 79.33%
# Epoch 40 | Batch 98/196 | loss: 0.623 | acc: 78.45%
# Epoch 40 | Batch 147/196 | loss: 0.630 | acc: 78.23%
# Epoch 40 | Batch 196/196 | loss: 0.601 | acc: 79.32%
# >> Epoch 40 SUMMARY: Val Acc: 76.36% | Current LR: 0.001
# Epoch 41 | Batch 49/196 | loss: 0.604 | acc: 79.42%
# Epoch 41 | Batch 98/196 | loss: 0.619 | acc: 78.38%
# Epoch 41 | Batch 147/196 | loss: 0.608 | acc: 78.59%
# Epoch 41 | Batch 196/196 | loss: 0.604 | acc: 78.83%
# >> Epoch 41 SUMMARY: Val Acc: 76.04% | Current LR: 0.001
# Epoch 42 | Batch 49/196 | loss: 0.600 | acc: 78.91%
# Epoch 42 | Batch 98/196 | loss: 0.606 | acc: 79.11%
# Epoch 42 | Batch 147/196 | loss: 0.620 | acc: 78.36%
# Epoch 42 | Batch 196/196 | loss: 0.606 | acc: 79.20%
# >> Epoch 42 SUMMARY: Val Acc: 75.79% | Current LR: 0.001
# Epoch 43 | Batch 49/196 | loss: 0.604 | acc: 79.08%
# Epoch 43 | Batch 98/196 | loss: 0.595 | acc: 79.21%
# Epoch 43 | Batch 147/196 | loss: 0.601 | acc: 79.39%
# Epoch 43 | Batch 196/196 | loss: 0.612 | acc: 78.61%
# >> Epoch 43 SUMMARY: Val Acc: 76.14% | Current LR: 0.001
# Epoch 44 | Batch 49/196 | loss: 0.596 | acc: 79.39%
# Epoch 44 | Batch 98/196 | loss: 0.595 | acc: 79.64%
# Epoch 44 | Batch 147/196 | loss: 0.601 | acc: 79.39%
# Epoch 44 | Batch 196/196 | loss: 0.610 | acc: 78.51%
# >> Epoch 44 SUMMARY: Val Acc: 76.59% | Current LR: 0.001
# Epoch 45 | Batch 49/196 | loss: 0.606 | acc: 78.98%
# Epoch 45 | Batch 98/196 | loss: 0.584 | acc: 79.98%
# Epoch 45 | Batch 147/196 | loss: 0.589 | acc: 80.05%
# Epoch 45 | Batch 196/196 | loss: 0.599 | acc: 79.25%
# >> Epoch 45 SUMMARY: Val Acc: 77.15% | Current LR: 0.001
# Epoch 46 | Batch 49/196 | loss: 0.577 | acc: 80.13%
# Epoch 46 | Batch 98/196 | loss: 0.578 | acc: 79.93%
# Epoch 46 | Batch 147/196 | loss: 0.593 | acc: 79.40%
# Epoch 46 | Batch 196/196 | loss: 0.629 | acc: 78.32%
# >> Epoch 46 SUMMARY: Val Acc: 75.78% | Current LR: 0.001
# Epoch 47 | Batch 49/196 | loss: 0.577 | acc: 79.80%
# Epoch 47 | Batch 98/196 | loss: 0.584 | acc: 79.96%
# Epoch 47 | Batch 147/196 | loss: 0.589 | acc: 79.45%
# Epoch 47 | Batch 196/196 | loss: 0.570 | acc: 80.22%
# >> Epoch 47 SUMMARY: Val Acc: 75.78% | Current LR: 0.001
# Epoch 48 | Batch 49/196 | loss: 0.575 | acc: 79.70%
# Epoch 48 | Batch 98/196 | loss: 0.588 | acc: 79.53%
# Epoch 48 | Batch 147/196 | loss: 0.574 | acc: 80.22%
# Epoch 48 | Batch 196/196 | loss: 0.574 | acc: 80.29%
# >> Epoch 48 SUMMARY: Val Acc: 77.04% | Current LR: 0.001
# Epoch 49 | Batch 49/196 | loss: 0.570 | acc: 80.32%
# Epoch 49 | Batch 98/196 | loss: 0.579 | acc: 79.67%
# Epoch 49 | Batch 147/196 | loss: 0.581 | acc: 80.05%
# Epoch 49 | Batch 196/196 | loss: 0.571 | acc: 80.23%
# >> Epoch 49 SUMMARY: Val Acc: 77.52% | Current LR: 0.001
# Epoch 50 | Batch 49/196 | loss: 0.556 | acc: 80.48%
# Epoch 50 | Batch 98/196 | loss: 0.565 | acc: 80.23%
# Epoch 50 | Batch 147/196 | loss: 0.586 | acc: 79.42%
# Epoch 50 | Batch 196/196 | loss: 0.592 | acc: 79.27%
# >> Epoch 50 SUMMARY: Val Acc: 75.76% | Current LR: 0.001
# Epoch 51 | Batch 49/196 | loss: 0.554 | acc: 80.48%
# Epoch 51 | Batch 98/196 | loss: 0.565 | acc: 80.01%
# Epoch 51 | Batch 147/196 | loss: 0.567 | acc: 80.40%
# Epoch 51 | Batch 196/196 | loss: 0.588 | acc: 79.31%
# >> Epoch 51 SUMMARY: Val Acc: 76.85% | Current LR: 0.001
# Epoch 52 | Batch 49/196 | loss: 0.563 | acc: 80.31%
# Epoch 52 | Batch 98/196 | loss: 0.569 | acc: 80.15%
# Epoch 52 | Batch 147/196 | loss: 0.558 | acc: 80.50%
# Epoch 52 | Batch 196/196 | loss: 0.558 | acc: 80.52%
# >> Epoch 52 SUMMARY: Val Acc: 77.42% | Current LR: 0.001
# Epoch 53 | Batch 49/196 | loss: 0.553 | acc: 80.80%
# Epoch 53 | Batch 98/196 | loss: 0.572 | acc: 80.17%
# Epoch 53 | Batch 147/196 | loss: 0.557 | acc: 80.64%
# Epoch 53 | Batch 196/196 | loss: 0.562 | acc: 80.37%
# >> Epoch 53 SUMMARY: Val Acc: 76.84% | Current LR: 0.001
# Epoch 54 | Batch 49/196 | loss: 0.532 | acc: 81.61%
# Epoch 54 | Batch 98/196 | loss: 0.559 | acc: 80.54%
# Epoch 54 | Batch 147/196 | loss: 0.559 | acc: 80.22%
# Epoch 54 | Batch 196/196 | loss: 0.569 | acc: 80.04%
# >> Epoch 54 SUMMARY: Val Acc: 77.58% | Current LR: 0.001
# Epoch 55 | Batch 49/196 | loss: 0.549 | acc: 80.98%
# Epoch 55 | Batch 98/196 | loss: 0.552 | acc: 80.83%
# Epoch 55 | Batch 147/196 | loss: 0.560 | acc: 80.55%
# Epoch 55 | Batch 196/196 | loss: 0.549 | acc: 80.81%
# >> Epoch 55 SUMMARY: Val Acc: 77.82% | Current LR: 0.001
# Epoch 56 | Batch 49/196 | loss: 0.552 | acc: 80.88%
# Epoch 56 | Batch 98/196 | loss: 0.540 | acc: 81.19%
# Epoch 56 | Batch 147/196 | loss: 0.554 | acc: 81.00%
# Epoch 56 | Batch 196/196 | loss: 0.557 | acc: 80.65%
# >> Epoch 56 SUMMARY: Val Acc: 78.00% | Current LR: 0.001
# Epoch 57 | Batch 49/196 | loss: 0.549 | acc: 81.16%
# Epoch 57 | Batch 98/196 | loss: 0.558 | acc: 80.52%
# Epoch 57 | Batch 147/196 | loss: 0.551 | acc: 80.76%
# Epoch 57 | Batch 196/196 | loss: 0.549 | acc: 81.06%
# >> Epoch 57 SUMMARY: Val Acc: 78.19% | Current LR: 0.001
# Epoch 58 | Batch 49/196 | loss: 0.540 | acc: 80.98%
# Epoch 58 | Batch 98/196 | loss: 0.550 | acc: 81.19%
# Epoch 58 | Batch 147/196 | loss: 0.541 | acc: 80.99%
# Epoch 58 | Batch 196/196 | loss: 0.542 | acc: 81.24%
# >> Epoch 58 SUMMARY: Val Acc: 77.82% | Current LR: 0.001
# Epoch 59 | Batch 49/196 | loss: 0.539 | acc: 81.35%
# Epoch 59 | Batch 98/196 | loss: 0.561 | acc: 80.48%
# Epoch 59 | Batch 147/196 | loss: 0.538 | acc: 81.27%
# Epoch 59 | Batch 196/196 | loss: 0.556 | acc: 80.55%
# >> Epoch 59 SUMMARY: Val Acc: 77.28% | Current LR: 0.001
# Epoch 60 | Batch 49/196 | loss: 0.531 | acc: 81.58%
# Epoch 60 | Batch 98/196 | loss: 0.531 | acc: 81.66%
# Epoch 60 | Batch 147/196 | loss: 0.545 | acc: 80.67%
# Epoch 60 | Batch 196/196 | loss: 0.558 | acc: 80.76%
# >> Epoch 60 SUMMARY: Val Acc: 78.01% | Current LR: 0.001
# Epoch 61 | Batch 49/196 | loss: 0.539 | acc: 81.38%
# Epoch 61 | Batch 98/196 | loss: 0.543 | acc: 81.19%
# Epoch 61 | Batch 147/196 | loss: 0.549 | acc: 81.02%
# Epoch 61 | Batch 196/196 | loss: 0.527 | acc: 81.41%
# >> Epoch 61 SUMMARY: Val Acc: 78.25% | Current LR: 0.001
# Epoch 62 | Batch 49/196 | loss: 0.531 | acc: 81.45%
# Epoch 62 | Batch 98/196 | loss: 0.540 | acc: 81.05%
# Epoch 62 | Batch 147/196 | loss: 0.528 | acc: 81.53%
# Epoch 62 | Batch 196/196 | loss: 0.559 | acc: 80.65%
# >> Epoch 62 SUMMARY: Val Acc: 77.61% | Current LR: 0.001
# Epoch 63 | Batch 49/196 | loss: 0.542 | acc: 81.07%
# Epoch 63 | Batch 98/196 | loss: 0.531 | acc: 81.32%
# Epoch 63 | Batch 147/196 | loss: 0.549 | acc: 80.66%
# Epoch 63 | Batch 196/196 | loss: 0.521 | acc: 81.75%
# >> Epoch 63 SUMMARY: Val Acc: 78.00% | Current LR: 0.001
# Epoch 64 | Batch 49/196 | loss: 0.523 | acc: 81.78%
# Epoch 64 | Batch 98/196 | loss: 0.535 | acc: 81.24%
# Epoch 64 | Batch 147/196 | loss: 0.520 | acc: 81.90%
# Epoch 64 | Batch 196/196 | loss: 0.532 | acc: 81.34%
# >> Epoch 64 SUMMARY: Val Acc: 77.85% | Current LR: 0.001
# Epoch 65 | Batch 49/196 | loss: 0.513 | acc: 81.79%
# Epoch 65 | Batch 98/196 | loss: 0.533 | acc: 81.31%
# Epoch 65 | Batch 147/196 | loss: 0.530 | acc: 81.85%
# Epoch 65 | Batch 196/196 | loss: 0.525 | acc: 81.92%
# >> Epoch 65 SUMMARY: Val Acc: 78.49% | Current LR: 0.001
# Epoch 66 | Batch 49/196 | loss: 0.529 | acc: 81.49%
# Epoch 66 | Batch 98/196 | loss: 0.515 | acc: 82.06%
# Epoch 66 | Batch 147/196 | loss: 0.535 | acc: 81.45%
# Epoch 66 | Batch 196/196 | loss: 0.534 | acc: 81.36%
# >> Epoch 66 SUMMARY: Val Acc: 78.34% | Current LR: 0.001
# Epoch 67 | Batch 49/196 | loss: 0.511 | acc: 82.06%
# Epoch 67 | Batch 98/196 | loss: 0.523 | acc: 81.75%
# Epoch 67 | Batch 147/196 | loss: 0.519 | acc: 82.10%
# Epoch 67 | Batch 196/196 | loss: 0.524 | acc: 81.90%
# >> Epoch 67 SUMMARY: Val Acc: 78.28% | Current LR: 0.001
# Epoch 68 | Batch 49/196 | loss: 0.519 | acc: 81.65%
# Epoch 68 | Batch 98/196 | loss: 0.525 | acc: 81.98%
# Epoch 68 | Batch 147/196 | loss: 0.523 | acc: 82.02%
# Epoch 68 | Batch 196/196 | loss: 0.518 | acc: 81.91%
# >> Epoch 68 SUMMARY: Val Acc: 78.72% | Current LR: 0.001
# Epoch 69 | Batch 49/196 | loss: 0.513 | acc: 82.17%
# Epoch 69 | Batch 98/196 | loss: 0.503 | acc: 82.49%
# Epoch 69 | Batch 147/196 | loss: 0.525 | acc: 81.73%
# Epoch 69 | Batch 196/196 | loss: 0.522 | acc: 81.95%
# >> Epoch 69 SUMMARY: Val Acc: 77.78% | Current LR: 0.001
# Epoch 70 | Batch 49/196 | loss: 0.510 | acc: 82.16%
# Epoch 70 | Batch 98/196 | loss: 0.498 | acc: 82.36%
# Epoch 70 | Batch 147/196 | loss: 0.537 | acc: 81.30%
# Epoch 70 | Batch 196/196 | loss: 0.523 | acc: 81.53%
# >> Epoch 70 SUMMARY: Val Acc: 78.53% | Current LR: 0.001
# Epoch 71 | Batch 49/196 | loss: 0.498 | acc: 82.65%
# Epoch 71 | Batch 98/196 | loss: 0.521 | acc: 81.76%
# Epoch 71 | Batch 147/196 | loss: 0.522 | acc: 82.05%
# Epoch 71 | Batch 196/196 | loss: 0.522 | acc: 81.57%
# >> Epoch 71 SUMMARY: Val Acc: 78.94% | Current LR: 0.001
# Epoch 72 | Batch 49/196 | loss: 0.497 | acc: 82.82%
# Epoch 72 | Batch 98/196 | loss: 0.505 | acc: 82.22%
# Epoch 72 | Batch 147/196 | loss: 0.509 | acc: 82.27%
# Epoch 72 | Batch 196/196 | loss: 0.542 | acc: 81.25%
# >> Epoch 72 SUMMARY: Val Acc: 79.00% | Current LR: 0.001
# Epoch 73 | Batch 49/196 | loss: 0.495 | acc: 82.84%
# Epoch 73 | Batch 98/196 | loss: 0.505 | acc: 81.89%
# Epoch 73 | Batch 147/196 | loss: 0.510 | acc: 82.41%
# Epoch 73 | Batch 196/196 | loss: 0.519 | acc: 82.11%
# >> Epoch 73 SUMMARY: Val Acc: 78.51% | Current LR: 0.001
# Epoch 74 | Batch 49/196 | loss: 0.504 | acc: 82.49%
# Epoch 74 | Batch 98/196 | loss: 0.504 | acc: 82.40%
# Epoch 74 | Batch 147/196 | loss: 0.510 | acc: 82.25%
# Epoch 74 | Batch 196/196 | loss: 0.505 | acc: 82.61%
# >> Epoch 74 SUMMARY: Val Acc: 78.36% | Current LR: 0.001
# Epoch 75 | Batch 49/196 | loss: 0.495 | acc: 83.07%
# Epoch 75 | Batch 98/196 | loss: 0.526 | acc: 81.95%
# Epoch 75 | Batch 147/196 | loss: 0.493 | acc: 82.70%
# Epoch 75 | Batch 196/196 | loss: 0.530 | acc: 82.00%
# >> Epoch 75 SUMMARY: Val Acc: 79.02% | Current LR: 0.001
# Epoch 76 | Batch 49/196 | loss: 0.490 | acc: 82.83%
# Epoch 76 | Batch 98/196 | loss: 0.510 | acc: 82.09%
# Epoch 76 | Batch 147/196 | loss: 0.490 | acc: 83.07%
# Epoch 76 | Batch 196/196 | loss: 0.519 | acc: 82.29%
# >> Epoch 76 SUMMARY: Val Acc: 78.87% | Current LR: 0.001
# Epoch 77 | Batch 49/196 | loss: 0.485 | acc: 83.10%
# Epoch 77 | Batch 98/196 | loss: 0.508 | acc: 82.44%
# Epoch 77 | Batch 147/196 | loss: 0.511 | acc: 82.37%
# Epoch 77 | Batch 196/196 | loss: 0.508 | acc: 82.71%
# >> Epoch 77 SUMMARY: Val Acc: 78.32% | Current LR: 0.001
# Epoch 78 | Batch 49/196 | loss: 0.499 | acc: 82.61%
# Epoch 78 | Batch 98/196 | loss: 0.518 | acc: 82.18%
# Epoch 78 | Batch 147/196 | loss: 0.486 | acc: 83.21%
# Epoch 78 | Batch 196/196 | loss: 0.505 | acc: 82.11%
# >> Epoch 78 SUMMARY: Val Acc: 79.37% | Current LR: 0.001
# Epoch 79 | Batch 49/196 | loss: 0.478 | acc: 83.18%
# Epoch 79 | Batch 98/196 | loss: 0.489 | acc: 82.70%
# Epoch 79 | Batch 147/196 | loss: 0.490 | acc: 83.00%
# Epoch 79 | Batch 196/196 | loss: 0.519 | acc: 81.97%
# >> Epoch 79 SUMMARY: Val Acc: 78.56% | Current LR: 0.001
# Epoch 80 | Batch 49/196 | loss: 0.499 | acc: 82.22%
# Epoch 80 | Batch 98/196 | loss: 0.507 | acc: 82.40%
# Epoch 80 | Batch 147/196 | loss: 0.486 | acc: 83.00%
# Epoch 80 | Batch 196/196 | loss: 0.502 | acc: 82.36%
# >> Epoch 80 SUMMARY: Val Acc: 78.95% | Current LR: 0.001
# Epoch 81 | Batch 49/196 | loss: 0.487 | acc: 83.30%
# Epoch 81 | Batch 98/196 | loss: 0.494 | acc: 83.00%
# Epoch 81 | Batch 147/196 | loss: 0.512 | acc: 82.31%
# Epoch 81 | Batch 196/196 | loss: 0.501 | acc: 82.33%
# >> Epoch 81 SUMMARY: Val Acc: 79.56% | Current LR: 0.001
# Epoch 82 | Batch 49/196 | loss: 0.478 | acc: 83.41%
# Epoch 82 | Batch 98/196 | loss: 0.490 | acc: 82.53%
# Epoch 82 | Batch 147/196 | loss: 0.490 | acc: 82.81%
# Epoch 82 | Batch 196/196 | loss: 0.504 | acc: 82.32%
# >> Epoch 82 SUMMARY: Val Acc: 78.99% | Current LR: 0.001
# Epoch 83 | Batch 49/196 | loss: 0.484 | acc: 82.96%
# Epoch 83 | Batch 98/196 | loss: 0.497 | acc: 82.77%
# Epoch 83 | Batch 147/196 | loss: 0.498 | acc: 82.61%
# Epoch 83 | Batch 196/196 | loss: 0.486 | acc: 83.09%
# >> Epoch 83 SUMMARY: Val Acc: 78.66% | Current LR: 0.001
# Epoch 84 | Batch 49/196 | loss: 0.497 | acc: 82.34%
# Epoch 84 | Batch 98/196 | loss: 0.470 | acc: 83.71%
# Epoch 84 | Batch 147/196 | loss: 0.492 | acc: 82.68%
# Epoch 84 | Batch 196/196 | loss: 0.497 | acc: 82.87%
# >> Epoch 84 SUMMARY: Val Acc: 79.28% | Current LR: 0.001
# Epoch 85 | Batch 49/196 | loss: 0.471 | acc: 83.45%
# Epoch 85 | Batch 98/196 | loss: 0.494 | acc: 83.08%
# Epoch 85 | Batch 147/196 | loss: 0.490 | acc: 83.00%
# Epoch 85 | Batch 196/196 | loss: 0.512 | acc: 82.23%
# >> Epoch 85 SUMMARY: Val Acc: 79.19% | Current LR: 0.001
# Epoch 86 | Batch 49/196 | loss: 0.478 | acc: 83.33%
# Epoch 86 | Batch 98/196 | loss: 0.475 | acc: 83.75%
# Epoch 86 | Batch 147/196 | loss: 0.499 | acc: 82.53%
# Epoch 86 | Batch 196/196 | loss: 0.495 | acc: 82.69%
# >> Epoch 86 SUMMARY: Val Acc: 78.63% | Current LR: 0.001
# Epoch 87 | Batch 49/196 | loss: 0.472 | acc: 83.54%
# Epoch 87 | Batch 98/196 | loss: 0.486 | acc: 82.84%
# Epoch 87 | Batch 147/196 | loss: 0.482 | acc: 83.42%
# Epoch 87 | Batch 196/196 | loss: 0.484 | acc: 82.92%
# >> Epoch 87 SUMMARY: Val Acc: 79.83% | Current LR: 0.001
# Epoch 88 | Batch 49/196 | loss: 0.466 | acc: 83.63%
# Epoch 88 | Batch 98/196 | loss: 0.480 | acc: 82.89%
# Epoch 88 | Batch 147/196 | loss: 0.483 | acc: 83.34%
# Epoch 88 | Batch 196/196 | loss: 0.489 | acc: 83.28%
# >> Epoch 88 SUMMARY: Val Acc: 79.33% | Current LR: 0.001
# Epoch 89 | Batch 49/196 | loss: 0.478 | acc: 83.39%
# Epoch 89 | Batch 98/196 | loss: 0.491 | acc: 83.08%
# Epoch 89 | Batch 147/196 | loss: 0.471 | acc: 83.68%
# Epoch 89 | Batch 196/196 | loss: 0.484 | acc: 83.19%
# >> Epoch 89 SUMMARY: Val Acc: 78.18% | Current LR: 0.001
# Epoch 90 | Batch 49/196 | loss: 0.467 | acc: 83.42%
# Epoch 90 | Batch 98/196 | loss: 0.490 | acc: 83.02%
# Epoch 90 | Batch 147/196 | loss: 0.489 | acc: 82.80%
# Epoch 90 | Batch 196/196 | loss: 0.503 | acc: 82.64%
# >> Epoch 90 SUMMARY: Val Acc: 79.94% | Current LR: 0.001
# Epoch 91 | Batch 49/196 | loss: 0.464 | acc: 83.82%
# Epoch 91 | Batch 98/196 | loss: 0.467 | acc: 83.39%
# Epoch 91 | Batch 147/196 | loss: 0.466 | acc: 83.39%
# Epoch 91 | Batch 196/196 | loss: 0.493 | acc: 82.74%
# >> Epoch 91 SUMMARY: Val Acc: 79.29% | Current LR: 0.001
# Epoch 92 | Batch 49/196 | loss: 0.473 | acc: 83.47%
# Epoch 92 | Batch 98/196 | loss: 0.485 | acc: 83.25%
# Epoch 92 | Batch 147/196 | loss: 0.488 | acc: 82.95%
# Epoch 92 | Batch 196/196 | loss: 0.469 | acc: 83.76%
# >> Epoch 92 SUMMARY: Val Acc: 78.63% | Current LR: 0.001
# Epoch 93 | Batch 49/196 | loss: 0.474 | acc: 83.40%
# Epoch 93 | Batch 98/196 | loss: 0.466 | acc: 83.68%
# Epoch 93 | Batch 147/196 | loss: 0.470 | acc: 83.71%
# Epoch 93 | Batch 196/196 | loss: 0.477 | acc: 83.36%
# >> Epoch 93 SUMMARY: Val Acc: 78.91% | Current LR: 0.001
# Epoch 94 | Batch 49/196 | loss: 0.472 | acc: 83.21%
# Epoch 94 | Batch 98/196 | loss: 0.459 | acc: 84.03%
# Epoch 94 | Batch 147/196 | loss: 0.476 | acc: 82.98%
# Epoch 94 | Batch 196/196 | loss: 0.486 | acc: 83.14%
# >> Epoch 94 SUMMARY: Val Acc: 79.33% | Current LR: 0.001
# Epoch 95 | Batch 49/196 | loss: 0.471 | acc: 83.35%
# Epoch 95 | Batch 98/196 | loss: 0.456 | acc: 84.21%
# Epoch 95 | Batch 147/196 | loss: 0.488 | acc: 82.91%
# Epoch 95 | Batch 196/196 | loss: 0.468 | acc: 83.84%
# >> Epoch 95 SUMMARY: Val Acc: 78.92% | Current LR: 0.001
# Epoch 96 | Batch 49/196 | loss: 0.466 | acc: 83.75%
# Epoch 96 | Batch 98/196 | loss: 0.468 | acc: 83.76%
# Epoch 96 | Batch 147/196 | loss: 0.472 | acc: 83.47%
# Epoch 96 | Batch 196/196 | loss: 0.471 | acc: 83.45%
# >> Epoch 96 SUMMARY: Val Acc: 78.93% | Current LR: 0.001
# Epoch 97 | Batch 49/196 | loss: 0.460 | acc: 84.02%
# Epoch 97 | Batch 98/196 | loss: 0.468 | acc: 84.02%
# Epoch 97 | Batch 147/196 | loss: 0.474 | acc: 83.48%
# Epoch 97 | Batch 196/196 | loss: 0.472 | acc: 83.55%
# >> Epoch 97 SUMMARY: Val Acc: 79.37% | Current LR: 0.001
# Epoch 98 | Batch 49/196 | loss: 0.467 | acc: 83.82%
# Epoch 98 | Batch 98/196 | loss: 0.454 | acc: 84.38%
# Epoch 98 | Batch 147/196 | loss: 0.468 | acc: 83.90%
# Epoch 98 | Batch 196/196 | loss: 0.479 | acc: 82.88%
# >> Epoch 98 SUMMARY: Val Acc: 79.60% | Current LR: 0.001
# Epoch 99 | Batch 49/196 | loss: 0.460 | acc: 83.78%
# Epoch 99 | Batch 98/196 | loss: 0.463 | acc: 83.67%
# Epoch 99 | Batch 147/196 | loss: 0.473 | acc: 83.57%
# Epoch 99 | Batch 196/196 | loss: 0.465 | acc: 83.53%
# >> Epoch 99 SUMMARY: Val Acc: 78.51% | Current LR: 0.001
# Epoch 100 | Batch 49/196 | loss: 0.459 | acc: 84.10%
# Epoch 100 | Batch 98/196 | loss: 0.472 | acc: 83.67%
# Epoch 100 | Batch 147/196 | loss: 0.469 | acc: 83.54%
# Epoch 100 | Batch 196/196 | loss: 0.486 | acc: 82.96%
# >> Epoch 100 SUMMARY: Val Acc: 79.54% | Current LR: 0.001
# Finished Training

# %% [markdown]
# ## 10. Test the network on the test data

# %%
dataIter = iter(vizLoader)
images, labels = next(dataIter)
# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(viz_batchSize)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# GroundTruth:  ship  plane plane frog

# %%
images, labels = images.to(device), labels.to(device)

outputs = net(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join(f'{classes[predicted[j].item()]:5s}' for j in range(len(predicted))))
# Out:
# Predicted:  ship  truck plane frog

# %% [markdown]
# ## 11. Test the network on the whole dataset

# %%
test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():
    for data in testLoader:
        images, labels = data[0].to(device), data[1].to(device)
        
        outputs = net(images)
        
        # 1. Calculate the loss for this batch
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        
        # 2. Calculate accuracy as before
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Calculate the average loss over all batches
avg_test_loss = test_loss / len(testLoader)

print(f'Test Loss: {avg_test_loss:.4f}')
print(f'Test Accuracy: {100 * correct / total:.2f}%')
# Out:
# Test Loss: 0.6264
# Test Accuracy: 79.27%

# %% [markdown]
# ## 12. Check performance within each class

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testLoader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1

# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: plane is 77.9 %
# Accuracy for class: car   is 86.0 %
# Accuracy for class: bird  is 76.9 %
# Accuracy for class: cat   is 59.2 %
# Accuracy for class: deer  is 74.4 %
# Accuracy for class: dog   is 74.8 %
# Accuracy for class: frog  is 90.6 %
# Accuracy for class: horse is 81.7 %
# Accuracy for class: ship  is 85.8 %
# Accuracy for class: truck is 90.3 %
